# %% [markdown]
# ## Magic Methods

# %% [markdown]
# ## Magic Method are also called as Dunder Methods Because they have doubke underscores __ before and after their name and they are special methods in python that allow us to customize how object behave.

# %% [markdown]
# ## These Method can help us define:
# ## 1. Object IntailizaTION  (__init__)
# ## 2. String Representation(__str__,__repr__)
# ## 3. Arthitmetic Operations(__add__,__sub__,etc)
# ## 4. Comparison OPerations (__eq__,__it__)
# ## 5. Length, indexing, iteration (__len__,__getitem__,etc)

# %% [markdown]
# ## Why to use magic Methods
#
# ## 1. Makes Objects behave like built in types (eg, likes , integers)
# ## 2. Improves Readability by allowing basic operation onject1 + object2
# ## 3. Simplifies code by replacing verbose function calls with natural syntax.

# %% [markdown]
# ## print(object) --> __str__--> what is returned when print(object) is used

# %% [markdown]
# ## Arithmetic operations can be done among the objects by using Magic Methods

# %%
class Avengers:
    def __init__(self,name,strength):
        self.name=name
        self.strength=strength

    def __add__
