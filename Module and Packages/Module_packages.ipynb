# %% [markdown]
# # Modules and Packages

# %%
def addition(num1,num2):
    return num1+num2

# %%
addition(5,6)
# Out:
# 11

# %% [markdown]
# ## I want to use this logic of the function i the file into the other files

# %%
import math
math.sqrt(16)
# Out:
# 4.0

# %% [markdown]
# ## Module---> A module in python is a file containing python code (functions, classes or varibles) that can be imported and used in other programs

# %% [markdown]
# ## Numpy---> Numpy Module is going to help us out with applying scientific calculation on the array and we can store our data by consuming less space and we can apply the operations with our array a bit more faster as compared to those of the list
# ## ---> we can Do it in NUMPY just because Numpy is having the collection of function and attributes which can help us to work effeciently with the array

# %% [markdown]
# ## PANDAS
#
# ## pandas we can use when we are going to work with the dataset for cleaning, pre processing, EDA, analysis with plotting as well

# %%
## Math Module 

import math
math.sqrt(16)
# Out:
# 4.0

# %%
from math import sqrt
sqrt(16)
# Out:
# 4.0

# %%
'''for import all function of the fuction math module''' 

from math import *
print(pi)
# Out:
# 3.141592653589793

# %%
''' A module:
1. A Module helps in code organization 
2. It promotes reusability
3. It keeps the code clean and maanageable'''

# %%
cos(90)
# Out:
# -0.4480736161291702

# %%
factorial(10)
# Out:
# 3628800

# %%
import numpy as np

# %%
list_items=[[1,2,3,4,5]]
numpy_array=np.array(list_items)
print(type(numpy_array))
print(numpy_array)
# Out:
# <class 'numpy.ndarray'>
# [[1 2 3 4 5]]

# %%
# !pip install seaborn

# %% [markdown]
# ### I am Trying to create my own library or module and in this library i want the functions and the attributes to be created on my own

# %%
'''__init__.py is a file that has to be their inside the package folder and this __init__.py file helps us out in defining our
packages and intializing their namesspace'''

# %%
'''## __init__.py file can remain empty and its completely fine but this file has to be their inside the package folder otherwise
 it will not be considered as a package and we will not be able to import it when we will be creating our new packages into
 package folder. '''

# %%
from Package_Folder.mathemathics import Addition

Addition(5,6)
# Out:
# 5

# %%
from Package_Folder.Sub_Packages.sum import *

addition(5,6)
# Out:
# 11
