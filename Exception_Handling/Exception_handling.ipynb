# %% [markdown]
# ## Exception Handling

# %%
print("Hello please dont provide denominator value as 0")
denominator=int(input("Hello please Enter the  Denominator for Division: "))
if denominator==0:
    print("I asked you to not to provide denominator as 0 but still you providedand hencce there is no result for you")
else:
    print(1/denominator)
# Out:
# Hello please dont provide denominator value as 0
# 0.16666666666666666

# %%
 ## Error<-->Exception 
 ## Exception handling <---> Error Handling

# %%
#### Exception Handling is a way in which if we are getting the Errorsin programming or if the user entered input causes an error,
# then instead of throwing an error we can raise an expection which can let the user know that the input is not correct or the given 
# input can come up as an Error. As we dont want to stop the execution of the program, so we raise an error which will let the user know
# that the current input is Not correct but the programmer, execution wont stop.    

# Execution are events that disrupt the normal flow of a program. they occur when an error is encountered during program execution

# %%
#### Differnet Types of Execution:

## zerodivisionError ---> dividing by zero
## filenotfounderError ---> File Not Found
## ValueError ---> Invalid Value
## TypeError --> Invalid Type

# %%
a=b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 a=b
#
# NameError: name 'b' is not defined

# %%
b=25
a=b

# %%
print(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 print(x)
#
# NameError: name 'x' is not defined

# %% [markdown]
# ## Exception Handling
# ## try Except Block

# %% [markdown]
# #### try:                {you are trying to run the operation which might throw that should}
# #### result=a/b
# #### except: {You are going to represent that if the error has been thrown that should happen}
# #### print("The division is not valid)

# %%
## try:
##        a=b
## except:
##         print("  First of all assign the value for b")

# %%
try:
    print(x)
except NameError:
    print("X is not define")
# Out:
# X is not define

# %%
print(c)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 print(c)
#
# NameError: name 'c' is not defined

# %%
try:
    print(c)
except NameError:
    print("a is not define")
# Out:
# a is not define

# %%
try:
    a=b
except:
    print("Value b is not assigned")
# Out:
# Value b is not assigned

# %%
try:
    a=b
except NameError as exception:
    print(exception)
# Out:
# name 'b' is not defined

# %%
try:
    print(x)
except NameError:
    print("Something else went wrong!")
except:
    print("Variable X is not define")
# Out:
# Something else went wrong!

# %%
den=int(input("Enter the denominator Value: "))
try:
    result=1/den
    print(result)
except ZeroDivisionError as ex:
    print(ex)
# Out:
# division by zero

# %%
den=int(input("Enter the denominator Value: "))
try:
    result=1/den
    print(result)
except ZeroDivisionError as ex1:
    print(ex)
# Out:
# 0.2

# %%
b=int(input("Enter the denominator"))
try:
    result=1/b
    print(result)
except ZeroDivisionError as ex1:
    print(ex1)
# Out:
# division by zero

# %%
print(hello)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 print(hello)
#
# NameError: name 'hello' is not defined

# %%
try:
    print(Hello)
except NameError:
    print("Something went wrong")
else:
    print("Nothing went wrong")
# Out:
# Something went wrong

# %%
try:
    print("Hello")
except NameError:
    print("Something went wrong")
else:
    print("Nothing went wrong")
# Out:
# Hello
# Nothing went wrong

# %%
try:
    print(x)
except:
    print("Something went Wrong")
finally:
    print("The 'try except' is finished")
# Out:
# Something went Wrong
# The 'try except' is finished

# %%
# Try to open and write to a file that is not writable:

try:
    f= open("demofile.txt")
    try:
        f.write("loprem ipsum")
    except:
        print("Something went wrong when writing the file")
    finally:
        f.close()
except:
        print("something went wrong when opening the file")
# Out:
# something went wrong when opening the file

# %% [markdown]
# # Raise an exception:
#
# ## As a Python developer you can choose to throw an exception if a condition occurs.
#
# ## To throw (or raise) an exception, use the raise keyword.

# %%
# Raise an error and stop the program if x is lower than 0:

x = -1
if x < 0:
    raise Exception("Sorry, no numbers below zero")
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[55], line 5
#       3 x = -1
#       4 if x < 0:
# ----> 5     raise Exception("Sorry, no numbers below zero")
#
# Exception: Sorry, no numbers below zero

# %% [markdown]
# ### The raise keyword is used to raise an exception.
#
# ### You can define what kind of error to raise, and the text to print to the user.

# %%
# Raise a TypeError if x is not an integer:

x = "hello"

if not type(x) is int:
    raise TypeError("Only interger are allowed")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[56], line 6
#       3 x = "hello"
#       5 if not type(x) is int:
# ----> 6     raise TypeError("Only interger are allowed")
#
# TypeError: Only interger are allowed

# %%
x = "hello"

if not type(x) is int:
    print("Only interger are allowed")
# Out:
# Only interger are allowed

# %%
a = b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 a = b
#
# NameError: name 'b' is not defined

# %%
try:
    a=b
except NameError as ex:
    print(ex)
# Out:
# name 'b' is not defined

# %%
num=int(input("Enter the number beatween 1 to 100:"))
den =1/num
print(den)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[8], line 2
#       1 num=int(input("Enter the number beatween 1 to 100:"))
# ----> 2 den =1/num
#       3 print(den)
#
# ZeroDivisionError: division by zero

# %%
num=int(input("Enter the number beatween 1 to 100:"))
try:
    den=1/num
    print(den)
except ZeroDivisionError as ex:
    print(f"not {ex}")
# Out:
# not division by zero

# %%
b=int(input("Enter the denominator: "))
try:
    result=1/b
    print(result)
    a=c
except ZeroDivisionError as ex1:
    print(ex1)
except NameError as ex2:
    print(ex2)
# Out:
# 1.0
# name 'c' is not defined

# %%
b=(input("Enter the denominator: "))
try:
    result=1/b
    print(result)
    a=c
except ZeroDivisionError as ex1:
    print(ex1)

except NameError as ex2:
    print(ex2)
    
except Exception as ex:
    print(ex)
# Out:
# unsupported operand type(s) for /: 'int' and 'str'

# %% [markdown]
# ## If we are getting the error and we are not aware that which specific error type it is then we can use the primary exception class which is Exception

# %% [markdown]
# ### The Parent Exception type must be mentioned at the end or Last as it is the parent class so only if the previous exception class will not catch the error then this final one will be able to catch it.

# %% [markdown]
# ### try block ---> is going to have the opertaion where we can except an error to occur
# ### except ---> which is used to handle the error ina way such that the program exceution shouldnt stop
#
# ### else--->  It will be conssisting of the code whichwe want to run idf the try block operation is working without throwing any error
# ### finally---> Finally block gets executed once we are done with  everything and even if we are getting an error or not still the code inside the finally block gets excuted

# %% [markdown]
# ## if try ---> code is not throwig an Error ---> Except ---> code will be running
# ## if try ---> code is not throwing an Error ---> Else ----> code will be running

# %%
num=int(input("Enter the Denominator: "))
try:
    result=1/num
except Exception as ex:
    print(ex)
else:
    print(f"The division result of your denomiantor is {result}")
# Out:
# division by zero

# %% [markdown]
# ### Set up a Database
# ### try:
#         code to steup the database
#     else:
#         further code that what excatly should happend once we are  done with successfully setting up the database
#
#     finally:
#         print("you are successfully done with setting up the database")

# %%
try :
    den=int(input("Enter the denominator value:"))
    result=1/den

    a=b ##if a=c
 
    den2=int(input("Enter the Second denominator value :"))
    result2=1/den2

except ZeroDivisionError as ex1:
    print(ex1)

except NameError as ex2:
    print(ex2)

except Exception as ex:
    print(ex)

else:
    print("The division of 1 by denomiantor: ",result)
    print("The division of 1 by denomiantor: ",result2)

finally:
    print("The program Execution is completely done now")
# Out:
# name 'c' is not defined
# The program Execution is completely done now

# %%
#Exception ----> FileNotFoundError

try:
    f=open("example.txt", 'r')
    content=f.read()
    print(content)

except FileNotFoundError as ex:
    print(ex)

finally:
    if 'f' in locals() and not file.closed():
        f.close()
        print('file closed')
# Out:
# [Errno 2] No such file or directory: 'example.txt'
