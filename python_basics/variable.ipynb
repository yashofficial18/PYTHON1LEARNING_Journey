# %%
age=23
Name = "Yash"
Height = 5.8
is_true=True

# %%
age
# Out:
# 23

# %%
Height
# Out:
# 5.8

# %%
Name
# Out:
# 'Yash'

# %%
print(age)
# Out:
# 23

# %%
print(age)
# Out:
# 23

# %%
print("My Name :",Name)
# Out:
# My Name : Yash

# %%
print("My Age :",age)
# Out:
# My Age : 23

# %%
'''heelo
yash'''
# Out:
# 'heelo\nyash'

# %%
'''Variables names must be Descriptive :
    Age=23
    Name='Yash'
    '''
# Out:
# "Variables names must be Descriptive :\n    Age=23\n    Name='Yash'\n    "

# %%
name ="Yash"
Name ="Yash"
name==Name
# Out:
# True

# %%
Age = 18
Name = "Yash"
Height = 5.11
is_true = True

# %%
print(type(Age))
# Out:
# <class 'int'>

# %%
print(Age)
# Out:
# 18

# %%
Age=input("Enter your Age")

# %%
print(Age)
# Out:
# 18

# %%
Age=float(input("Enter your Age"))

# %%
print(type(Age))
# Out:
# <class 'float'>

# %%
## Simple Calculator

value_1=int(input("Enter the First Value: "))
value_2=int(input("Enter the Second Value: "))
print("The Addition for the Values is: ",value_1+value_2)
print("The Subtraction for the Values is: ",value_1-value_2)
print("The Multiplication for the Values is: ",value_1*value_2)
print("The Division for the Values is: ",value_1/value_2)
# Out:
# The Addition for the Values is:  32
# The Subtraction for the Values is:  -2
# The Multiplication for the Values is:  255
# The Division for the Values is:  0.8823529411764706
