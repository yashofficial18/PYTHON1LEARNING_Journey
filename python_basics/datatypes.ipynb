# %%
age = input("what is your age: ")

# %%
age
# Out:
# '88'

# %%
age2 = input("what is your age: ")

# %%
age2
# Out:
# '90'

# %%
print(age+age2)
# Out:
# 8890

# %%
a=23

# %%
type(a)
# Out:
# int

# %%
c=14.4

# %%
type(c)
# Out:
# float

# %%
a=7
b=7

a==b
# Out:
# True

# %%
is_type=True

# %%
type(is_type)
# Out:
# bool
